# %%
import pandas as pd

df = pd.read_csv('../data/processed/df_processed.csv')
df.head()
# Out:
#    역명  요일  상하구분  시간대   혼잡도          날짜  KBO  공휴일  가중치  COEX_가중치  COEX
# 0  13   2     0  330  27.9  2026-01-01    0    0  0.0       0.0     0
# 1  13   2     0  330  27.9  2026-01-02    0    0  0.0       0.0     0
# 2  13   2     0  330  27.9  2026-01-05    0    0  0.0       0.0     0
# 3  13   2     0  330  27.9  2026-01-06    0    0  0.0       0.0     0
# 4  13   2     0  330  27.9  2026-01-07    0    0  0.0       0.0     0
